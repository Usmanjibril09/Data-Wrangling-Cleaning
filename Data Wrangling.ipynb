# %% [markdown]
# # Data Wrangling and Cleaning

# %%
import pandas as pd

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
GradSurv = pd.read_csv("Graduate Survey.csv") #importing dataset

# %%
GradSurv.head()
# Out:
#          Timestamp What is your gender  Year of graduation  \
# 0    2/8/2018 9:05                Male                2013
# 1  2/15/2018 12:11                Male                2014
# 2  2/15/2018 13:47              Female                2013
# 3  2/16/2018 13:01                Male                2017
# 4  2/16/2018 13:18              Female                2013
#
#                              Title of course studied  \
# 0                Electrical & Electronic Engineering
# 1                                         Psychology
# 2                                          Economics
# 3  Mass Communication (Communication and Language...
# 4                                         Statistics
#
#         Polytechnic/University attended  \
# 0    Obafemi Awolowo University,Ile-Ife
# 1    Obafemi Awolowo University,Ile-Ife
# 2  Bells University of Technology, Otta
# 3                 Bowen University, Iwo
# 4                Ekiti State University
#
# ...

# %%
GradSurv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5219 entries, 0 to 5218
# Data columns (total 36 columns):
#  #   Column                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                        --------------  -----
#  0   Timestamp                                                                                                                     5219 non-null   object
#  1   What is your gender                                                                                                           5219 non-null   object
#  2   Year of graduation                                                                                                            5219 non-null   int64
# ...

# %%
#renaming columns using a dictionary

df = GradSurv.rename(columns={"What is your gender":"Gender","Title of course studied":"Course",
                                   "Polytechnic/University attended":"Institution","What is your highest level of education?":"Highest Qualification",
                                    "What best describes your current status?":"Employment Status","How many jobs have you had since graduation including your current one?":"Nos of Jobs",
                                   "If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?":"Year of NYSC Completion",
                                   "Approximately how many hours a day do you currently work?":"Working hours" })
df.head()
# Out:
#          Timestamp  Gender  Year of graduation  \
# 0    2/8/2018 9:05    Male                2013
# 1  2/15/2018 12:11    Male                2014
# 2  2/15/2018 13:47  Female                2013
# 3  2/16/2018 13:01    Male                2017
# 4  2/16/2018 13:18  Female                2013
#
#                                               Course  \
# 0                Electrical & Electronic Engineering
# 1                                         Psychology
# 2                                          Economics
# 3  Mass Communication (Communication and Language...
# 4                                         Statistics
#
#                             Institution Highest Qualification  \
# 0    Obafemi Awolowo University,Ile-Ife     Bachelor's degree
# 1    Obafemi Awolowo University,Ile-Ife     Bachelor's degree
# 2  Bells University of Technology, Otta     Bachelor's degree
# 3                 Bowen University, Iwo       Master's degree
# ...

# %%
#Delete  some columns  from the dataframe.
df1=df.drop(["What currency are you currently paid in?", "Which form of transport do you use the most?",
                         "Which of these skills/knowledge did your higher education prepare you for?",
                         "As far as you are aware, what was most important to your current employer about your qualification?",
                         "Which form of transport do you use the most?","Were you able to rent an apartment or buy a car from the salary you got from your first job?",
                         "My course of study prepared me well for further studies","Which of these skills/knowledge did your higher education prepare you for?",
                         "As far as you are aware, what was most important to your current employer about your qualification?", "Did you need your higher education qualification to get this job (the actual qualification, not the subject of study)?",
               "What was the most significant reason for deciding to take this job?","Reason why?"],
                         axis=1)

# %%
df1
# Out:
#             Timestamp  Gender  Year of graduation  \
# 0       2/8/2018 9:05    Male                2013
# 1     2/15/2018 12:11    Male                2014
# 2     2/15/2018 13:47  Female                2013
# 3     2/16/2018 13:01    Male                2017
# 4     2/16/2018 13:18  Female                2013
# ...               ...     ...                 ...
# 5214  5/14/2018 19:51  Female                2014
# 5215  5/15/2018 10:17  Female                2017
# 5216  5/15/2018 10:33  Female                2014
# 5217  5/15/2018 13:49  Female                2015
# 5218  5/15/2018 23:39    Male                2016
#
#                                                  Course  \
# 0                   Electrical & Electronic Engineering
# 1                                            Psychology
# 2                                             Economics
# 3     Mass Communication (Communication and Language...
# 4                                            Statistics
# ...

# %%
df1.iloc[:,:]#cheaking for the for all the rows and columns in the data set
# Out:
#             Timestamp  Gender  Year of graduation  \
# 0       2/8/2018 9:05    Male                2013
# 1     2/15/2018 12:11    Male                2014
# 2     2/15/2018 13:47  Female                2013
# 3     2/16/2018 13:01    Male                2017
# 4     2/16/2018 13:18  Female                2013
# ...               ...     ...                 ...
# 5214  5/14/2018 19:51  Female                2014
# 5215  5/15/2018 10:17  Female                2017
# 5216  5/15/2018 10:33  Female                2014
# 5217  5/15/2018 13:49  Female                2015
# 5218  5/15/2018 23:39    Male                2016
#
#                                                  Course  \
# 0                   Electrical & Electronic Engineering
# 1                                            Psychology
# 2                                             Economics
# 3     Mass Communication (Communication and Language...
# 4                                            Statistics
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5219 entries, 0 to 5218
# Data columns (total 27 columns):
#  #   Column                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                        --------------  -----
#  0   Timestamp                                                                                                                     5219 non-null   object
#  1   Gender                                                                                                                        5219 non-null   object
#  2   Year of graduation                                                                                                            5219 non-null   int64
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of             Timestamp  Gender  Year of graduation  \
# 0       2/8/2018 9:05    Male                2013
# 1     2/15/2018 12:11    Male                2014
# 2     2/15/2018 13:47  Female                2013
# 3     2/16/2018 13:01    Male                2017
# 4     2/16/2018 13:18  Female                2013
# ...               ...     ...                 ...
# 5214  5/14/2018 19:51  Female                2014
# 5215  5/15/2018 10:17  Female                2017
# 5216  5/15/2018 10:33  Female                2014
# 5217  5/15/2018 13:49  Female                2015
# 5218  5/15/2018 23:39    Male                2016
#
#                                                  Course  \
# 0                   Electrical & Electronic Engineering
# 1                                            Psychology
# 2                                             Economics
# 3     Mass Communication (Communication and Language...
# ...

# %%
df1.count()#shows the the counts of all the enteries on the variables.
# Out:
# Timestamp                                                                                                                       5219
# Gender                                                                                                                          5219
# Year of graduation                                                                                                              5219
# Course                                                                                                                          5219
# Institution                                                                                                                     5219
# Highest Qualification                                                                                                           5219
# Employment Status                                                                                                               5219
# ...

# %%
pd.crosstab(df1.Course, df1.Institution).head()# this shows the the number students that graduated from each course, in each Institution
# Out:
# Institution                              Abdu Gusau Polytechnic, Talata Mafara, Zamfara State.  \
# Course
# Accountancy                                                                              0
# Acturial Science                                                                         0
# Adult Education and Extra-Mural Studies                                                  0
# Agricultural Economics                                                                   0
# Agricultural Extension                                                                   0
#
# Institution                              Abia State Polytechnic, Aba, Abia State.  \
# Course
# Accountancy                                                                     2
# Acturial Science                                                                0
# Adult Education and Extra-Mural Studies                                         0
# ...

# %%
df1.isnull()# cheacking for missing values in the dataset.
# Out:
#       Timestamp  Gender  Year of graduation  Course  Institution  \
# 0         False   False               False   False        False
# 1         False   False               False   False        False
# 2         False   False               False   False        False
# 3         False   False               False   False        False
# 4         False   False               False   False        False
# ...         ...     ...                 ...     ...          ...
# 5214      False   False               False   False        False
# 5215      False   False               False   False        False
# 5216      False   False               False   False        False
# 5217      False   False               False   False        False
# 5218      False   False               False   False        False
#
#       Highest Qualification  Employment Status  Nos of Jobs  \
# 0                     False              False        False
# 1                     False              False        False
# ...

# %%
df2=df1.dropna(axis=0)# droping all the rows with missing values

df2
# Out:
#             Timestamp  Gender  Year of graduation  \
# 4     2/16/2018 13:18  Female                2013
# 5     2/16/2018 16:44    Male                2015
# 6      2/19/2018 7:24    Male                2013
# 8      2/19/2018 8:53  Female                2017
# 10     2/19/2018 9:19    Male                2015
# ...               ...     ...                 ...
# 5196  5/10/2018 17:35    Male                2017
# 5204  5/10/2018 20:30  Female                2015
# 5208  5/12/2018 16:47    Male                2016
# 5211  5/13/2018 15:32  Female                2015
# 5217  5/15/2018 13:49  Female                2015
#
#                                              Course  \
# 4                                        Statistics
# 5               Electrical & Electronic Engineering
# 6                                         Economics
# 8     Industrial Relations and Personnel Management
# 10                                        Economics
# ...

# %%
df2.info()# finally check that all missing values are removed.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1250 entries, 4 to 5217
# Data columns (total 27 columns):
#  #   Column                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                        --------------  -----
#  0   Timestamp                                                                                                                     1250 non-null   object
#  1   Gender                                                                                                                        1250 non-null   object
#  2   Year of graduation                                                                                                            1250 non-null   int64
# ...

# %%
df2[df2.Course=='Economics']# this brings out all the the records whose cources are Economics
# Out:
#             Timestamp  Gender  Year of graduation     Course  \
# 6      2/19/2018 7:24    Male                2013  Economics
# 10     2/19/2018 9:19    Male                2015  Economics
# 16    2/19/2018 12:36    Male                2015  Economics
# 18    2/19/2018 13:31  Female                2017  Economics
# 26    2/20/2018 12:51  Female                2017  Economics
# ...               ...     ...                 ...        ...
# 4956   5/4/2018 14:17  Female                2014  Economics
# 5106   5/8/2018 11:29  Female                2013  Economics
# 5110   5/8/2018 11:54    Male                2013  Economics
# 5195  5/10/2018 17:28    Male                2014  Economics
# 5211  5/13/2018 15:32  Female                2015  Economics
#
#                                             Institution  \
# 6                                 Bowen University, Iwo
# 10                                 University of Ibadan
# 16                   Obafemi Awolowo University,Ile-Ife
# ...

# %%
df2[(df2.Course == 'Statistics') & (df.Gender == 'Male')] # this shows the record of male students who offer Economics
# Out:
#             Timestamp Gender  Year of graduation      Course  \
# 137   2/21/2018 15:01   Male                2015  Statistics
# 896   2/27/2018 12:57   Male                2015  Statistics
# 1977   3/7/2018 11:28   Male                2015  Statistics
# 2224    3/8/2018 7:57   Male                2014  Statistics
# 2326   3/9/2018 16:13   Male                2013  Statistics
# 3266   3/26/2018 9:26   Male                2013  Statistics
# 3394  3/27/2018 13:22   Male                2016  Statistics
# 3570   4/3/2018 13:25   Male                2015  Statistics
# 5142   5/9/2018 12:16   Male                2015  Statistics
#
#                                             Institution  \
# 137                  Obafemi Awolowo University,Ile-Ife
# 896   Delta State Polytechnic, Ogwashi-Uku, Delta St...
# 1977                               University of Ibadan
# 2224                               University of Ibadan
# 2326      Kwara State Polytechnic, Ilorin, Kwara State.
# ...

# %%
df2.head()
# Out:
#           Timestamp  Gender  Year of graduation  \
# 4   2/16/2018 13:18  Female                2013
# 5   2/16/2018 16:44    Male                2015
# 6    2/19/2018 7:24    Male                2013
# 8    2/19/2018 8:53  Female                2017
# 10   2/19/2018 9:19    Male                2015
#
#                                            Course              Institution  \
# 4                                      Statistics   Ekiti State University
# 5             Electrical & Electronic Engineering      University of Benin
# 6                                       Economics    Bowen University, Iwo
# 8   Industrial Relations and Personnel Management  Covenant University Ota
# 10                                      Economics     University of Ibadan
#
#             Highest Qualification  \
# 4               Bachelor's degree
# 5               Bachelor's degree
# 6   Higher National Diploma (HND)
# 8               Bachelor's degree
# 10              Bachelor's degree
#
# ...

# %%
filterby_instition=df2["Institution"]=="University of Ibadan"
print(filterby_instition)
# Out:
# 4       False
# 5       False
# 6       False
# 8       False
# 10       True
#         ...
# 5196    False
# 5204    False
# 5208    False
# 5211    False
# 5217    False
# Name: Institution, Length: 1250, dtype: bool

# %%
institution_filter=df2[filterby_instition]
print(institution_filter)
# Out:
#             Timestamp  Gender  Year of graduation  \
# 10     2/19/2018 9:19    Male                2015
# 365   2/24/2018 19:05    Male                2015
# 491    2/26/2018 3:51    Male                2015
# 556    2/27/2018 4:52    Male                2015
# 596    2/27/2018 6:48  Female                2017
# 615    2/27/2018 7:26    Male                2015
# 696    2/27/2018 8:52    Male                2015
# 740    2/27/2018 9:44  Female                2014
# 758   2/27/2018 10:07  Female                2017
# 825   2/27/2018 11:13  Female                2014
# 849   2/27/2018 11:35    Male                2015
# 895   2/27/2018 12:55  Female                2015
# 992   2/27/2018 17:25    Male                2016
# 1184  2/28/2018 20:07  Female                2017
# 1353   3/1/2018 19:54  Female                2014
# 1434   3/2/2018 10:58    Male                2015
# 1489   3/2/2018 16:53    Male                2014
# 1573    3/3/2018 6:14    Male                2015
# ...

# %%
df2.loc[100:300,["Course","Employment Status","What is your current monthly income level?"]]
# this qurry seeks to find out the relationship between the course, work status and income, from rows 100-300, against 3 columns
# Out:
#                                                 Course  \
# 100      Industrial Relations and Personnel Management
# 106                                  Political Science
# 107  Vocational Teacher Education (Technical Educat...
# 108                                        Accountancy
# 113                                         Physiology
# 115             Forest Resources Management (Forestry)
# 116                  History and International Studies
# 123                            Business Administration
# 125  Pharmaceutical Technology and Industrial Pharmacy
# 126                                        Accountancy
# 129                                            Anatomy
# 130                                   Computer Science
# 134                           Theatre and Film Studies
# 135                   Foreign Languages and Literature
# 137                                         Statistics
# 139                                                Law
# ...

# %%
df2.filter( lambda x: x["What is your current monthly income level?"].mean()> ₦20,000)
# Out:
#   File "<ipython-input-46-a4a1c25529ee>", line 1
#     df2.filter( lambda x: x["What is your current monthly income level?"].mean()> ₦20,000)
#                                                                                     ^
# SyntaxError: invalid character in identifier

# %%
dropcol=["What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1","Which employer in the country do you think offers the best opportunities for graduates?",
             "How do you find out about your job(s)?"] #create new df after dropping the fo;;owing columns with coldrop

# %%
dffinal=df2.drop(dropcol, axis=1)
dffinal.head()
# Out:
#           Timestamp  Gender  Year of graduation  \
# 4   2/16/2018 13:18  Female                2013
# 5   2/16/2018 16:44    Male                2015
# 6    2/19/2018 7:24    Male                2013
# 8    2/19/2018 8:53  Female                2017
# 10   2/19/2018 9:19    Male                2015
#
#                                            Course              Institution  \
# 4                                      Statistics   Ekiti State University
# 5             Electrical & Electronic Engineering      University of Benin
# 6                                       Economics    Bowen University, Iwo
# 8   Industrial Relations and Personnel Management  Covenant University Ota
# 10                                      Economics     University of Ibadan
#
#             Highest Qualification  \
# 4               Bachelor's degree
# 5               Bachelor's degree
# 6   Higher National Diploma (HND)
# 8               Bachelor's degree
# 10              Bachelor's degree
#
# ...

# %%
dffinal.describe()
# Out:
#        Year of graduation  Year of NYSC Completion  Working hours
# count         1250.000000              1250.000000    1250.000000
# mean          2014.724000              2016.184800       9.070800
# std              1.232655                 1.423893       2.532967
# min           2013.000000              2013.000000       0.000000
# 25%           2014.000000              2015.000000       8.000000
# 50%           2015.000000              2016.000000       9.000000
# 75%           2016.000000              2017.000000      10.000000
# max           2017.000000              2019.000000      24.000000

# %%
dffinal1=dffinal.groupby("What is your job role?")
dffinal1.get_group("Software Developer")
# this sort the data set where business is the job role in the data frame
# Out:
#             Timestamp  Gender  Year of graduation  \
# 6      2/19/2018 7:24    Male                2013
# 10     2/19/2018 9:19    Male                2015
# 731    2/27/2018 9:35    Male                2015
# 763   2/27/2018 10:13    Male                2017
# 1295   3/1/2018 17:25    Male                2015
# 1347   3/1/2018 19:36  Female                2014
# 1516   3/2/2018 18:00    Male                2016
# 1713   3/6/2018 11:41    Male                2016
# 1726   3/6/2018 12:55    Male                2015
# 2071   3/7/2018 13:02    Male                2014
# 2074   3/7/2018 13:06    Male                2015
# 2561  3/11/2018 10:24    Male                2015
# 3329  3/26/2018 14:49    Male                2015
# 3580   4/3/2018 13:41    Male                2015
# 3841   4/5/2018 13:39  Female                2017
# 4011  4/12/2018 11:21    Male                2015
# 4467  4/24/2018 13:11  Female                2015
# 4617  4/27/2018 23:24    Male                2016
# ...

# %%
import matplotlib.pyplot as plt

# %%
import json

# %%
import seaborn as sb

# %%
plt.rcParams['figure.figsize'] = 8, 4

# %%
dffinal2_gender = df.groupby('Gender')

# %%
dffinal3_job = df.groupby('What is your job role?')
dffinal3_job.size().plot(kind='bar')

# %%
dffinal3_job.size()
# Out:
# What is your job role?
# Architect                                             36
# Back-End Developer                                    15
# Blue-collar/Artisan                                   29
# Business Analyst                                      93
# Business Developer                                   111
# Business Support                                      69
# Civil Engineer                                        42
# Content Creator/Content Writer/ Content Developer    101
# Creatives                                             70
# Customer Service                                     394
# Data Entry                                           117
# Devops Engineer                                        8
# Doctor, Nursing And Other Medical Related Roles       96
# Estate Management                                     40
# Event Management                                      28
# Executive Assistance/Personal Assitance              101
# ...

# %%
dffinal2_gender.size().plot(kind='bar')

# %%
dffinal2_gender

# %%
dffinal2_gender.size()
# Out:
# Gender
# Female               2592
# Male                 2624
# Prefer not to say       3
# dtype: int64

# %%
dffinal4_course = df.groupby('My course of study prepared me well for employment')
dffinal4_course.size().plot(kind='bar')

# %%
dffinal4_course.size()
# Out:
# My course of study prepared me well for employment
# Agree                1574
# Disagree              640
# No                      1
# Strongly Agree        808
# Strongly Disagree     409
# dtype: int64

# %%
dffinal5_salary = df.groupby('What is your current monthly income level?')
dffinal5_salary.size().plot(kind='bar')

# %%
dffinal5_salary.size()
# Out:
# What is your current monthly income level?
# Under ‎₦20,000            642
# ‎₦100,000 - ‎₦149,999     373
# ‎₦150,000 - ‎₦199,999     181
# ‎₦20,000 - ‎₦49,999      1057
# ‎₦200,000 - ‎₦249,999      86
# ‎₦250,000 and more        118
# ‎₦50,000 - ‎₦99,999       975
# dtype: int64

# %%
cour_gen = df2.groupby(['Course','Gender']) #getting a group using course and gender

cour_gen.get_group(('Economics', 'Male'))[['Institution', 'Year of graduation']]
# Out:
#                                             Institution  Year of graduation
# 6                                 Bowen University, Iwo                2013
# 10                                 University of Ibadan                2015
# 16                   Obafemi Awolowo University,Ile-Ife                2015
# 86                      Babcock University,Ilishan-Remo                2014
# 145               Olabisi Onabanjo University Ago-Iwoye                2014
# 607                                 University of Lagos                2017
# 688                     Babcock University,Ilishan-Remo                2015
# 706                                 University of Lagos                2014
# 871                         University of Port-Harcourt                2015
# 963                                 University of Lagos                2017
# 1146                      University of Nigeria, Nsukka                2015
# ...

# %%
cour_gen.size()
# Out:
# Course                                              Gender
# Accountancy                                         Female    51
#                                                     Male      36
# Acturial Science                                    Female     1
#                                                     Male       2
# Adult Education and Extra-Mural Studies             Female     1
#                                                               ..
# Veterinary Medicine                                 Male       1
# Vocational Teacher Education (Technical Education)  Female     1
#                                                     Male       1
# Zoology                                             Female     3
#                                                     Male       2
# Length: 189, dtype: int64

# %%
df2[(df2.Course == 'Statistics') & (df.Gender == 'Male')]\
    [['Institution', 'Year of graduation','What is your job role?','What is your current monthly income level?','Employment Status']]
# Out:
#                                             Institution  Year of graduation  \
# 137                  Obafemi Awolowo University,Ile-Ife                2015
# 896   Delta State Polytechnic, Ogwashi-Uku, Delta St...                2015
# 1977                               University of Ibadan                2015
# 2224                               University of Ibadan                2014
# 2326      Kwara State Polytechnic, Ilorin, Kwara State.                2013
# 3266                              Bowen University, Iwo                2013
# 3394                               University of Ilorin                2016
# 3570               University of Agriculture, Abeokuta.                2015
# 5142               Auchi Polytechnic, Auchi, Edo State.                2015
#
#      What is your job role? What is your current monthly income level?  \
# 137              Researcher                        ‎₦50,000 - ‎₦99,999
# ...
